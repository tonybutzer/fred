# %%
# %%bash
#
# cd ~
# wget https://cicwebresources.blob.core.windows.net/chesapeakebaylandcover/DC/DC_11001.zip
# Out:
# --2022-05-26 01:24:21--  https://cicwebresources.blob.core.windows.net/chesapeakebaylandcover/DC/DC_11001.zip
# Resolving cicwebresources.blob.core.windows.net (cicwebresources.blob.core.windows.net)... 52.239.214.132
# Connecting to cicwebresources.blob.core.windows.net (cicwebresources.blob.core.windows.net)|52.239.214.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21829091 (21M) [application/zip]
# Saving to: ‘DC_11001.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  308K 69s
#     50K .......... .......... .......... .......... ..........  0%  608K 52s
#    100K .......... .......... .......... .......... ..........  0% 26.8M 35s
#    150K .......... .......... .......... .......... ..........  0% 1.17M 30s
#    200K .......... .......... .......... .......... ..........  1% 1.18M 28s
#    250K .......... .......... .......... .......... ..........  1% 30.0M 23s
# ...

# %%
! ls ~
# Out:
#  0_picotte_Folder	        bunny.obj	    my_condas
#  Attic			       'conda rise.ipynb'   opt
#  Baywide_13Class_20132014.tif   iarpa		    play
#  DC_11001.zip		        junk		    rise_play_claudia.ipynb
#  Untitled.ipynb		        lidar-cloud	   'test presentation.ipynb'
#  Untitled1.ipynb	        maine_one_tile.nc

# %%
! mkdir ~/dc; unzip /home/jovyan/DC_11001.zip
# Out:
# Archive:  /home/jovyan/DC_11001.zip
#    creating: DC_11001/
#   inflating: DC_11001/DC_11001.img
#   inflating: DC_11001/DC_11001.img.aux.xml
#   inflating: DC_11001/DC_11001.img.vat.dbf
#   inflating: DC_11001/DC_11001.img.xml
#   inflating: DC_11001/DC_11001.rrd
#  extracting: DC_11001/Dist_11001.img.vat.cpg

# %%
! (cd ~; wget https://cicwebresources.blob.core.windows.net/chesapeakebaylandcover/BAYWIDE/Baywide_7Class_20132014.zip)
# Out:
# --2022-05-26 01:27:08--  https://cicwebresources.blob.core.windows.net/chesapeakebaylandcover/BAYWIDE/Baywide_7Class_20132014.zip
# Resolving cicwebresources.blob.core.windows.net (cicwebresources.blob.core.windows.net)... 52.239.214.132
# Connecting to cicwebresources.blob.core.windows.net (cicwebresources.blob.core.windows.net)|52.239.214.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9537657730 (8.9G) [application/x-zip-compressed]
# Saving to: ‘Baywide_7Class_20132014.zip’
#
# Baywide_7Class_2013   7%[>                   ] 665.12M   495KB/s    in 14m 21s
#
# 2022-05-26 01:56:30 (791 KB/s) - Read error at byte 697434112/9537657730 (Success). Retrying.
#
# --2022-05-26 01:56:31--  (try: 2)  https://cicwebresources.blob.core.windows.net/chesapeakebaylandcover/BAYWIDE/Baywide_7Class_20132014.zip
# Connecting to cicwebresources.blob.core.windows.net (cicwebresources.blob.core.windows.net)|52.239.214.132|:443... connected.
# ...
