# %%
import os
os.environ["PATH"] += os.pathsep + "/home/jovyan"
import numpy as np
import libtiff
import cv2

tif = libtiff.TIFF.open("HUGETIFFILE.tif", 'r')
width = tif.GetField("ImageWidth")
height = tif.GetField("ImageLength")
bits = tif.GetField('BitsPerSample')
sample_format = tif.GetField('SampleFormat')

ResizeFactor = 10 #Reduce Image Size by 10
Chunks = 8 #Read Image in 8 Chunks to prevent Memory Error (can be increased for 
# bigger files)

ReadStrip = tif.ReadEncodedStrip
typ = tif.get_numpy_type(bits, sample_format)


#ReadStrip
newarr = np.zeros((1, width/ResizeFactor), typ)
for ii in range(0,Chunks):
    pos = 0
    arr = np.empty((height/Chunks, width), typ)
    size = arr.nbytes
    for strip in range((ii*tif.NumberOfStrips()/Chunks),((ii+1)*tif.NumberOfStrips()/Chunks)):
        elem = ReadStrip(strip, arr.ctypes.data + pos, max(size-pos, 0))
        pos = pos + elem

    resized = cv2.resize(arr, (0,0), fx=float(1)/float(ResizeFactor), fy=float(1)/float(ResizeFactor))

    # Now remove the large array to free up Memory for the next chunk
    del arr
    # Finally recombine the individual resized chunks into the final resized image.
    newarr = np.vstack((newarr,resized))

newarr = np.delete(newarr, (0), axis=0)
cv2.imwrite('resized.tif', newarr)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b7b42d7f2fd7> in <module>
#       2 os.environ["PATH"] += os.pathsep + "/home/jovyan"
#       3 import numpy as np
# ----> 4 import libtiff
#       5 import cv2
#       6
#
# ModuleNotFoundError: No module named 'libtiff'

# %%
! pip install --user libtiff
# Out:
# Collecting libtiff
#   Downloading libtiff-0.4.2.tar.gz (129 kB)
#      |████████████████████████████████| 129 kB 4.0 MB/s eta 0:00:01
# Building wheels for collected packages: libtiff
#   Building wheel for libtiff (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /srv/conda/envs/pangeo/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"'; __file__='"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-zv16q2am
#        cwd: /tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/
#   Complete output (158 lines):
#   Warning: Assuming default configuration (libtiff/bitarray-a1646c0/bitarray/{setup_bitarray,setup}.py was not found)
#   Appending libtiff.bitarray configuration to libtiff
#   Ignoring attempt to set 'name' (from 'libtiff' to 'libtiff.bitarray')
#   Appending libtiff configuration to
#   Ignoring attempt to set 'name' (from '' to 'libtiff')
#   0.4.2
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building extension "bittools" sources
#   building extension "tif_lzw" sources
#   building extension "libtiff.bitarray._bitarray" sources
#   building extension "libtiff.bittools" sources
#   building extension "libtiff.tif_lzw" sources
#   building data_files sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_3.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_files.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/test_bittools.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/setup.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_3_9_5.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_9.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/script_options.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/optparse_gui.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_7.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_base.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_8.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_array.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_sample_plane.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_image.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/libtiff_ctypes.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/__init__.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/utils.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/lzw.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_channels_and_files.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/lsm.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_6.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_3_9_4.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_3_8_2.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_file.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_1.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_4_0_2.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_data.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/tiff_h_3_9_2.py -> build/lib.linux-x86_64-3.7/libtiff
#   copying libtiff/version.py -> build/lib.linux-x86_64-3.7/libtiff
#   creating build/lib.linux-x86_64-3.7/libtiff/bitarray
#   copying libtiff/bitarray-a1646c0/bitarray/__init__.py -> build/lib.linux-x86_64-3.7/libtiff/bitarray
#   copying libtiff/bitarray-a1646c0/bitarray/test_bitarray.py -> build/lib.linux-x86_64-3.7/libtiff/bitarray
#   running build_ext
#   customize UnixCCompiler
#   customize UnixCCompiler using build_ext
#   CCompilerOpt.cc_test_flags[1008] : testing flags (-march=native)
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   creating /tmp/tmpcncqd50l/srv
#   creating /tmp/tmpcncqd50l/srv/conda
#   creating /tmp/tmpcncqd50l/srv/conda/envs
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils
#   creating /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   extra options: '-march=native'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -march=native) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.cc_test_flags[1012] : testing failed
#   CCompilerOpt.cc_test_flags[1008] : testing flags (-O3)
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   extra options: '-O3'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -O3) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.cc_test_flags[1012] : testing failed
#   CCompilerOpt.cc_test_flags[1008] : testing flags (-Werror)
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   extra options: '-Werror'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -Werror) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.cc_test_flags[1012] : testing failed
#   CCompilerOpt.__init__[1696] : check requested baseline
#   CCompilerOpt.cc_test_flags[1008] : testing flags (-msse)
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   extra options: '-msse'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.cc_test_flags[1012] : testing failed
#   CCompilerOpt.cc_test_flags[1008] : testing flags (-msse2)
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   extra options: '-msse2'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse2) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.cc_test_flags[1012] : testing failed
#   CCompilerOpt.feature_test[1463] : testing feature 'SSE2' with flags ()
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.o.d) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.feature_test[1477] : testing failed
#   CCompilerOpt.feature_test[1463] : testing feature 'SSE' with flags ()
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#   CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.c -o /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.o -MMD -MF /tmp/tmpcncqd50l/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.o.d) failed with exit status 127 output ->
#   b''
#   CCompilerOpt.feature_test[1477] : testing failed
#   CCompilerOpt.__init__[1705] : check requested dispatch-able features
#   CCompilerOpt.__init__[1721] : initialize targets groups
#   CCompilerOpt.__init__[1723] : parse target group simd_test
#   CCompilerOpt._parse_target_tokens[1936] : skip targets (FMA4 AVX512_SKX AVX512F VSX2 (AVX2 FMA3) VSX VSX3 SSE2 NEON SSE42 XOP ASIMD) not part of baseline or dispatch-able features
#   CCompilerOpt.generate_dispatch_header[2267] : generate CPU dispatch header: (build/src.linux-x86_64-3.7/numpy/distutils/include/npy_cpu_dispatch_config.h)
#   CCompilerOpt.generate_dispatch_header[2278] : dispatch header dir build/src.linux-x86_64-3.7/numpy/distutils/include does not exist, creating it
#   building 'bittools' extension
#   compiling C sources
#   C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#   creating build/temp.linux-x86_64-3.7/libtiff
#   creating build/temp.linux-x86_64-3.7/libtiff/src
#   compile options: '-I/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.7/numpy/distutils/include -I/srv/conda/envs/pangeo/include/python3.7m -c'
#   gcc: libtiff/src/bittools.c
#   error: Command "gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.7/numpy/distutils/include -I/srv/conda/envs/pangeo/include/python3.7m -c libtiff/src/bittools.c -o build/temp.linux-x86_64-3.7/libtiff/src/bittools.o -MMD -MF build/temp.linux-x86_64-3.7/libtiff/src/bittools.o.d" failed with exit status 127
#
#   ########### EXT COMPILER OPTIMIZATION ###########
#   Platform      :
#     Architecture: x64
#     Compiler    : gcc
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : none
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : none
#     Generated   : none
#   CCompilerOpt.cache_flush[804] : write cache to path -> /tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/build/temp.linux-x86_64-3.7/ccompiler_opt_cache_ext.py
#   ----------------------------------------
#   ERROR: Failed building wheel for libtiff
#   Running setup.py clean for libtiff
# Failed to build libtiff
# Installing collected packages: libtiff
#     Running setup.py install for libtiff ... error
#     ERROR: Command errored out with exit status 1:
#      command: /srv/conda/envs/pangeo/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"'; __file__='"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-q2dx0qnt/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/jovyan/.local/include/python3.7m/libtiff
#          cwd: /tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/
#     Complete output (280 lines):
#     Warning: Assuming default configuration (libtiff/bitarray-a1646c0/bitarray/{setup_bitarray,setup}.py was not found)
#     Appending libtiff.bitarray configuration to libtiff
#     Ignoring attempt to set 'name' (from 'libtiff' to 'libtiff.bitarray')
#     Appending libtiff configuration to
#     Ignoring attempt to set 'name' (from '' to 'libtiff')
#     0.4.2
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building extension "bittools" sources
#     building extension "tif_lzw" sources
#     building extension "libtiff.bitarray._bitarray" sources
#     building extension "libtiff.bittools" sources
#     building extension "libtiff.tif_lzw" sources
#     building data_files sources
#     build_src: building npy-pkg config files
#     running build_py
#     creating build/lib.linux-x86_64-3.7
#     creating build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_3.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_files.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/test_bittools.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/setup.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_3_9_5.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_9.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/script_options.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/optparse_gui.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_7.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_base.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_8.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_array.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_sample_plane.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_image.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/libtiff_ctypes.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/__init__.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/utils.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/lzw.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_channels_and_files.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/lsm.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_6.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_3_9_4.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_3_8_2.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_file.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_1.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_4_0_2.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_data.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/tiff_h_3_9_2.py -> build/lib.linux-x86_64-3.7/libtiff
#     copying libtiff/version.py -> build/lib.linux-x86_64-3.7/libtiff
#     creating build/lib.linux-x86_64-3.7/libtiff/bitarray
#     copying libtiff/bitarray-a1646c0/bitarray/__init__.py -> build/lib.linux-x86_64-3.7/libtiff/bitarray
#     copying libtiff/bitarray-a1646c0/bitarray/test_bitarray.py -> build/lib.linux-x86_64-3.7/libtiff/bitarray
#     running build_ext
#     customize UnixCCompiler
#     customize UnixCCompiler using build_ext
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-march=native)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     creating /tmp/tmpjbmzs2yw/srv
#     creating /tmp/tmpjbmzs2yw/srv/conda
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils
#     creating /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-march=native'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -march=native) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-O3)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-O3'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -O3) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-Werror)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-Werror'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -Werror) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.__init__[1696] : check requested baseline
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-msse)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-msse'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-msse2)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-msse2'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse2) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'SSE' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'SSE2' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse2.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.__init__[1705] : check requested dispatch-able features
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-msse3)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-msse3'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse3) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mssse3)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mssse3'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mssse3) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'SSSE3' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_ssse3.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_ssse3.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_ssse3.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-msse4.1)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-msse4.1'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse4.1) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mpopcnt)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mpopcnt'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mpopcnt) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'POPCNT' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_popcnt.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_popcnt.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_popcnt.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'SSE3' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse3.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse3.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_sse3.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-msse4.2)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-msse4.2'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -msse4.2) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mavx)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mavx'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mavx) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mf16c)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mf16c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mf16c) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mfma)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mfma'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mfma) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mavx2)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mavx2'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mavx2) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mavx512f)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mavx512f'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mavx512f) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mavx512cd)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mavx512cd'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mavx512cd) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.cc_test_flags[1008] : testing flags (-mavx512er -mavx512pf)
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     extra options: '-mavx512er -mavx512pf'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/test_flags.o.d -mavx512er -mavx512pf) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.cc_test_flags[1012] : testing failed
#     CCompilerOpt.feature_test[1463] : testing feature 'AVX512_KNL' with flags ()
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     compile options: '-I/srv/conda/envs/pangeo/include/python3.7m -c'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[713] : Command (gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/include/python3.7m -c /srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_avx512_knl.c -o /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_avx512_knl.o -MMD -MF /tmp/tmpjbmzs2yw/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/distutils/checks/cpu_avx512_knl.o.d) failed with exit status 127 output ->
#     b''
#     CCompilerOpt.feature_test[1477] : testing failed
#     CCompilerOpt.__init__[1721] : initialize targets groups
#     CCompilerOpt.__init__[1723] : parse target group simd_test
#     CCompilerOpt._parse_target_tokens[1936] : skip targets (FMA4 AVX512F SSE42 NEON VSX3 VSX SSE2 (FMA3 AVX2) XOP VSX2 ASIMD AVX512_SKX) not part of baseline or dispatch-able features
#     CCompilerOpt.generate_dispatch_header[2267] : generate CPU dispatch header: (build/src.linux-x86_64-3.7/numpy/distutils/include/npy_cpu_dispatch_config.h)
#     building 'bittools' extension
#     compiling C sources
#     C compiler: gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC
#
#     creating build/temp.linux-x86_64-3.7/libtiff
#     creating build/temp.linux-x86_64-3.7/libtiff/src
#     compile options: '-I/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.7/numpy/distutils/include -I/srv/conda/envs/pangeo/include/python3.7m -c'
#     gcc: libtiff/src/bittools.c
#     error: Command "gcc -pthread -B /srv/conda/envs/pangeo/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/srv/conda/envs/pangeo/lib/python3.7/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.7/numpy/distutils/include -I/srv/conda/envs/pangeo/include/python3.7m -c libtiff/src/bittools.c -o build/temp.linux-x86_64-3.7/libtiff/src/bittools.o -MMD -MF build/temp.linux-x86_64-3.7/libtiff/src/bittools.o.d" failed with exit status 127
#
#     ########### EXT COMPILER OPTIMIZATION ###########
#     Platform      :
#       Architecture: x64
#       Compiler    : gcc
#
#     CPU baseline  :
#       Requested   : 'min'
#       Enabled     : none
#       Flags       : none
#       Extra checks: none
#
#     CPU dispatch  :
#       Requested   : 'max -xop -fma4'
#       Enabled     : none
#       Generated   : none
#     CCompilerOpt.cache_flush[804] : write cache to path -> /tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/build/temp.linux-x86_64-3.7/ccompiler_opt_cache_ext.py
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /srv/conda/envs/pangeo/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"'; __file__='"'"'/tmp/pip-install-yir8lpmo/libtiff_b34334a3bb7b4fdc86b993ce196870fd/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-q2dx0qnt/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/jovyan/.local/include/python3.7m/libtiff Check the logs for full command output.
